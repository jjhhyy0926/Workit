# %%
# !pip install -q openai
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
exec(open("/content/drive/MyDrive/plan_seed_generate_colab.py").read())
# Out:
# 생성 목표: 불가 32 + 충족/미흡 300 = 332개
#
# 불가 샘플 완료: 32개
#
# [  1/300] 1. 사업명 | 명확성 | 충족
# [  2/300] 1. 사업명 | 명확성 | 미흡
# [  3/300] 1. 사업명 | 일관성 | 충족
# [  4/300] 1. 사업명 | 일관성 | 미흡
# [  5/300] 1. 사업명 | 이해가능성 | 충족
# [  6/300] 1. 사업명 | 이해가능성 | 미흡
# [  7/300] 1. 사업명 | 정확성 | 충족
# [  8/300] 1. 사업명 | 정확성 | 미흡
# [  9/300] 1. 사업명 | 정확성 | 충족
# [ 10/300] 1. 사업명 | 정확성 | 미흡
# [ 11/300] 2. 사업기간 | 이해가능성 | 충족
# [ 12/300] 2. 사업기간 | 이해가능성 | 미흡
# [ 13/300] 2. 사업기간 | 검증가능성 | 충족
# [ 14/300] 2. 사업기간 | 검증가능성 | 미흡
# [ 15/300] 3. 사업목적 | 완전성 | 충족
# [ 16/300] 3. 사업목적 | 완전성 | 미흡
# [ 17/300] 3. 사업목적 | 정확성 | 충족
# [ 18/300] 3. 사업목적 | 정확성 | 미흡
# [ 19/300] 3. 사업목적 | 명확성 | 충족
# [ 20/300] 3. 사업목적 | 명확성 | 미흡
#   >>> 중간 저장: 52개 → /content/drive/MyDrive/workit_sft/plan_seed_partial_10.json
#
# [ 21/300] 3. 사업목적 | 명확성 | 충족
# [ 22/300] 3. 사업목적 | 명확성 | 미흡
# [ 23/300] 3. 사업목적 | 명확성 | 충족
# [ 24/300] 3. 사업목적 | 명확성 | 미흡
# [ 25/300] 3. 사업목적 | 일관성 | 충족
# [ 26/300] 3. 사업목적 | 일관성 | 미흡
# [ 27/300] 3. 사업목적 | 일관성 | 충족
# ...
